# %%
cd drive/My Drive/penguin_search
# Out:
# /content/drive/My Drive/penguin_search

# %%
cd images
# Out:
# /content/drive/My Drive/penguin_search/images

# %%
names = ['RoyalPenguin', 'ChinstrapPenguin']

# names = ['GalapagosPenguin', 'KingPenguin',
#          'White-flipperedPenguin','HumboldtPenguin','MagellanicPenguin','AfricanPenguin','LittlePenguin',
#          'ChinstrapPenguin','FiordlandPenguin','Erect-crestedPenguin','SnaresIslandsPenguin','RoyalPenguin',
#          'MacaroniPenguin','AdeliePenguin','GentooPenguin','Yellow-eyedPenguin']

# %%
import os
import glob

# %%
for name in names:
  path = "./{}".format(name)
  files = glob.glob(path + '/*')
  print(name, '--start--')
  for f in files:
      os.rename(f, os.path.join(path, name + '_' + os.path.basename(f)))
# Out:
# RoyalPenguin --start--
# ChinstrapPenguin --start--
